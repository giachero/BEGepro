# %%
# %%capture
#""%matplotlib inline
# %matplotlib notebook

# %load_ext autoreload
# %autoreload 2

# %reset -f

import numpy as np
import pylab as plt
from matplotlib.lines import Line2D
from begepro.rw import CAENhandler_new as ca

# %%
filename='/home/marco/work/tesi/data/Std-232Th-3Bq-AEcalibration-im010421/Std-232Th-3Bq-AEcalibration-im010421.npy'
coll=ca.NPYreader(filename,True).get_event()

# %%
#MSE ae<1.6

coll1=coll.subset('ae',0,1.6e-2)
curr1=coll1.get_curr()
trace1=coll1.get_traces()

plt.figure()
   
plt.plot(curr1[0]/np.linalg.norm(curr1[0]))
plt.plot(trace1[0]/np.linalg.norm(trace1[0]))
plt.show()

plt.figure()

for i in range(10):
    plt.plot(curr1[i])  #se li normalizzo il grafico diventa brutto
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
#SSE ae>1.6

coll2=coll.subset('ae',cutmin=1.6e-2)
curr2=coll2.get_curr()
trace2=coll2.get_traces()

plt.figure()
   
plt.plot(curr2[0]/np.linalg.norm(curr2[0]))
plt.plot(trace2[0]/np.linalg.norm(trace2[0]))
plt.show()

plt.figure()

for i in range(10):
    plt.plot(curr2[i])  #se li normalizzo il grafico diventa brutto
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
curr=coll.get_curr()
trace=coll.get_traces()

# %%
plt.figure()
for i in range(4,5):    
    plt.plot(curr[i].astype(np.float64)/np.linalg.norm(curr[i]))
    plt.plot(trace[i]/np.linalg.norm(trace[i]))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#segnale p+?
plt.figure()
for i in range(3,4):    
    plt.plot(curr[i].astype(np.float64)/np.linalg.norm(curr[i]))
    plt.plot(trace[i]/np.linalg.norm(trace[i]))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
