# %% [markdown]
# ## Example notebook
# This example code reads the data from the xml file and creates the histogram of maximum-minumum values

# %%
# %%capture
#""%matplotlib inline
# %matplotlib notebook

# %load_ext autoreload
# %autoreload 2

# %reset -f

# %%
from begepro.rw import CAENhandler
import numpy as np
import pylab as plt

# %%
filename='/home/giachero/data/BEGe/wave1_228Th_N44.dat'
dr=CAENhandler.wavedumpReader(filename)
Mm =list()
ch = 1    # Channel to analyze
N  = 5000 # Set to None for acquire all che events

# %%
data=dr.get()
for key in [k for k in data.keys() if k != 'trace']:
    print (key,':',data[key])
# Out:
# size : 16024
# boardid : 31
# pattern : 0
# ch : 0
# counter : 7
# ttag : 104501
# evsize : 8000

# %%
plt.plot(data['trace'])
plt.xlabel(r'Time [Samples]')
plt.ylabel(r'Amplitude [ADC count]')
plt.grid(True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
