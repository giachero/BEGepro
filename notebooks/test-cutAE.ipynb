# %%
# %%capture
#""%matplotlib inline
# %matplotlib notebook

# %load_ext autoreload
# %autoreload 2

# %reset -f

import numpy as np
import pylab as plt
from begepro.rw import CAENhandler_new as ca

# %%
#filename='/home/marco/work/tesi/data/Std-232Th-3Bq-AEcalibration-im010421_0.npy'
filename='/home/marco/work/tesi/data/228Th-grafico-tesi-im260421_1/228Th-grafico-tesi-im260421_1_0.npy'

coll=ca.NPYreader(filename,True).get_event()

# %%
nbits=14
nbins=2**14-1
calVec = [-0.090383 + 0.20574*i for i in range(2**14+1)]

# %%
import pylab as plt
plt.figure()
plt.hist(coll.get_energies(), bins=calVec, histtype='step', alpha=0.7)
#plt.semilogy()
plt.grid(axis='x')

#1593KeV is the double escape of 208Tl. Expected to be composed by SSE
plt.xlim(1580,1600)
plt.ylim(0,50)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 50.0)

# %%
cutmin=1590; cutmax=1596
coll2=coll.subset('energy',cutmin,cutmax)
plt.hist(coll2.get_energies(), bins=calVec, histtype='step',facecolor='c',edgecolor='k',fill=True)
# Out:
# (array([0., 0., 0., ..., 0., 0., 0.]),
#  array([-9.03830000e-02,  1.15357000e-01,  3.21097000e-01, ...,
#          3.37034230e+03,  3.37054804e+03,  3.37075378e+03]),
#  [<matplotlib.patches.Polygon at 0x7fe01f021e50>])

# %%
trace=coll2.get_traces()
plt.figure()
for i in range(50):
    plt.plot(trace[i,:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist(coll.get_energies(), bins=calVec, histtype='step', alpha=0.7)
#plt.semilogy()
plt.grid(axis='x')

#2104KeV is the single escape of 208Tl. Expected to be composed by MSE
plt.xlim(2098,2110)
plt.ylim(0,50)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 50.0)

# %%
cutmin=2102; cutmax=2106
coll3=coll.subset('energy',cutmin,cutmax)
plt.hist(coll3.get_energies(), bins=calVec, histtype='step',facecolor='c',edgecolor='k',fill=True)
# Out:
# (array([0., 0., 0., ..., 0., 0., 0.]),
#  array([-9.03830000e-02,  1.15357000e-01,  3.21097000e-01, ...,
#          3.37034230e+03,  3.37054804e+03,  3.37075378e+03]),
#  [<matplotlib.patches.Polygon at 0x7fe01edcc580>])

# %%
trace=coll3.get_traces()
plt.figure()
for i in range(50):
    plt.plot(trace[i,:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist(coll.get_energies(), bins=calVec, histtype='step', alpha=0.7)
#plt.semilogy()
plt.grid(axis='x')

#2615keV is photo-peak of 208Tl. Expected to be composed by MSE
plt.xlim(2600,2630)
plt.ylim(0,150)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 150.0)

# %%
cutmin=2607; cutmax=2619;
coll4=coll.subset('energy',cutmin,cutmax)
plt.hist(coll4.get_energies(), bins=calVec, histtype='step',facecolor='c',edgecolor='k',fill=True)
# Out:
# (array([0., 0., 0., ..., 0., 0., 0.]),
#  array([-9.03830000e-02,  1.15357000e-01,  3.21097000e-01, ...,
#          3.37034230e+03,  3.37054804e+03,  3.37075378e+03]),
#  [<matplotlib.patches.Polygon at 0x7fe01f344e50>])

# %%
trace=coll4.get_traces()
plt.figure()
for i in range(50):
    plt.plot(trace[i,:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Despite the energy,the events with A/E <1.6e-2 should be mostly MSE

cutmin=0; cutmax=1.6e-2;
coll5=coll.subset('ae',cutmin,cutmax)

# %%
trace=coll5.get_traces()
plt.figure()
for i in range(10):
    plt.plot(trace[i,:])
# Out:
# <img src="data:image/png;base64,..." width="640">
